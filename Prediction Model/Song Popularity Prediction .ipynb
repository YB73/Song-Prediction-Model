# %%
import numpy as np
import seaborn as sns 
import pandas as pd 
from matplotlib import pyplot as plt
# %matplotlib inline
sns.set_style("whitegrid")

import warnings 
warnings.filterwarnings("ignore")

# %%
dataframe = pd.read_csv('C:/Users/Moina/train.csv/train.csv')
dataframe.head()
# Out:
#    id                           name release_date  \
# 0   0             Ya Solo Eres Mi Ex   2021-09-09
# 1   1                         Nibiru   2019-11-29
# 2   2                          DAMN.   2017-04-14
# 3   3  Did I Shave My Legs For This?   1996-01-01
# 4   4                        glisten   2018-05-04
#
#                                     artists  total_tracks  \
# 0  La Adictiva Banda San José de Mesillas,              7
# 1                                   Ozuna,             18
# 2                          Kendrick Lamar,             14
# 3                            Deana Carter,             11
# 4                           Jeremy Zucker,              4
#
#                       t_name0                 t_name1                 t_name2  \
# 0          Ya Solo Eres Mi Ex            La Malagueña  México Lindo y Querido
# 1                      Nibiru  Hasta Que Salga el Sol                Temporal
# ...

# %%
dataframe.describe()
# Out:
#                   id   total_tracks        t_dur0        t_dur1        t_dur2  \
# count  160000.000000  160000.000000  1.600000e+05  1.122840e+05  1.084670e+05
# mean    79999.500000      11.004150  1.991346e+05  2.135132e+05  2.143228e+05
# std     46188.165873      23.007852  1.160741e+05  1.112099e+05  9.868120e+04
# min         0.000000       1.000000  1.485000e+03  4.120000e+03  4.285000e+03
# 25%     39999.750000       1.000000  1.508040e+05  1.688312e+05  1.693190e+05
# 50%     79999.500000      10.000000  1.920520e+05  2.036260e+05  2.064400e+05
# 75%    119999.250000      14.000000  2.336000e+05  2.426525e+05  2.449730e+05
# max    159999.000000    1190.000000  1.082819e+07  7.054236e+06  6.145123e+06
#
#             t_dance0       t_dance1       t_dance2      t_energy0  \
# count  159786.000000  112159.000000  108390.000000  159786.000000
# mean        0.606401       0.608607       0.609624       0.605095
# std         0.184056       0.177404       0.179375       0.236601
# ...

# %%
print(dataframe.keys())
# Out:
# Index(['id', 'name', 'release_date', 'artists', 'total_tracks', 't_name0',
#        't_name1', 't_name2', 't_dur0', 't_dur1', 't_dur2', 't_dance0',
#        't_dance1', 't_dance2', 't_energy0', 't_energy1', 't_energy2', 't_key0',
#        't_key1', 't_key2', 't_mode0', 't_mode1', 't_mode2', 't_speech0',
#        't_speech1', 't_speech2', 't_acous0', 't_acous1', 't_acous2', 't_ins0',
#        't_ins1', 't_ins2', 't_live0', 't_live1', 't_live2', 't_val0', 't_val1',
#        't_val2', 't_tempo0', 't_tempo1', 't_tempo2', 't_sig0', 't_sig1',
#        't_sig2', 'popularity'],
#       dtype='object')

# %%
pd.isnull(dataframe).sum()
# Out:
# id                  0
# name                0
# release_date        0
# artists             0
# total_tracks        0
# t_name0             0
# t_name1         47716
# t_name2         51533
# t_dur0              0
# t_dur1          47716
# t_dur2          51533
# t_dance0          214
# t_dance1        47841
# t_dance2        51610
# t_energy0         214
# t_energy1       47841
# t_energy2       51610
# t_key0            214
# t_key1          47841
# t_key2          51610
# t_mode0           214
# t_mode1         47841
# t_mode2         51610
# t_speech0         214
# t_speech1       47841
# t_speech2       51610
# t_acous0          214
# t_acous1        47841
# t_acous2        51610
# t_ins0            214
# t_ins1          47841
# t_ins2          51610
# t_live0           214
# t_live1         47841
# t_live2         51610
# t_val0            214
# t_val1          47841
# t_val2          51610
# t_tempo0          214
# t_tempo1        47841
# t_tempo2        51610
# ...

# %%
df1 = dataframe.dropna()

# %%
pd.isnull(dataframe).sum()
# Out:
# id                  0
# name                0
# release_date        0
# artists             0
# total_tracks        0
# t_name0             0
# t_name1         47716
# t_name2         51533
# t_dur0              0
# t_dur1          47716
# t_dur2          51533
# t_dance0          214
# t_dance1        47841
# t_dance2        51610
# t_energy0         214
# t_energy1       47841
# t_energy2       51610
# t_key0            214
# t_key1          47841
# t_key2          51610
# t_mode0           214
# t_mode1         47841
# t_mode2         51610
# t_speech0         214
# t_speech1       47841
# t_speech2       51610
# t_acous0          214
# t_acous1        47841
# t_acous2        51610
# t_ins0            214
# t_ins1          47841
# t_ins2          51610
# t_live0           214
# t_live1         47841
# t_live2         51610
# t_val0            214
# t_val1          47841
# t_val2          51610
# t_tempo0          214
# t_tempo1        47841
# t_tempo2        51610
# ...

# %%
dataframe = dataframe.dropna()

# %%
pd.isnull(dataframe).sum()
# Out:
# id              0
# name            0
# release_date    0
# artists         0
# total_tracks    0
# t_name0         0
# t_name1         0
# t_name2         0
# t_dur0          0
# t_dur1          0
# t_dur2          0
# t_dance0        0
# t_dance1        0
# t_dance2        0
# t_energy0       0
# t_energy1       0
# t_energy2       0
# t_key0          0
# t_key1          0
# t_key2          0
# t_mode0         0
# t_mode1         0
# t_mode2         0
# t_speech0       0
# t_speech1       0
# t_speech2       0
# t_acous0        0
# t_acous1        0
# t_acous2        0
# t_ins0          0
# t_ins1          0
# t_ins2          0
# t_live0         0
# t_live1         0
# t_live2         0
# t_val0          0
# t_val1          0
# t_val2          0
# t_tempo0        0
# t_tempo1        0
# t_tempo2        0
# t_sig0          0
# t_sig1          0
# t_sig2          0
# popularity      0
# dtype: int64

# %%
sns.distplot(dataframe['popularity']).set_title('Popularity Distribution')
# Out:
# Text(0.5, 1.0, 'Popularity Distribution')

# %%
dataframe.corr()
# Out:
#                     id  total_tracks    t_dur0    t_dur1    t_dur2  t_dance0  \
# id            1.000000      0.004336 -0.004336 -0.003221 -0.004942  0.002726
# total_tracks  0.004336      1.000000 -0.101335 -0.041292 -0.066605 -0.070796
# t_dur0       -0.004336     -0.101335  1.000000  0.473132  0.476156 -0.040377
# t_dur1       -0.003221     -0.041292  0.473132  1.000000  0.657308 -0.092968
# t_dur2       -0.004942     -0.066605  0.476156  0.657308  1.000000 -0.083651
# t_dance0      0.002726     -0.070796 -0.040377 -0.092968 -0.083651  1.000000
# t_dance1      0.000115     -0.072408 -0.126388 -0.125660 -0.117369  0.557561
# t_dance2      0.004098     -0.055617 -0.118590 -0.104666 -0.121802  0.537319
# t_energy0     0.000427     -0.096802  0.106604  0.034519  0.049721  0.172297
# t_energy1    -0.000261     -0.076002 -0.030382  0.034904  0.044528  0.082415
# t_energy2     0.001364     -0.079887 -0.011853  0.027917  0.065218  0.090695
# ...

# %%
sns.barplot(x = 't_sig0', y = 'popularity', data = dataframe)
plt.title('Popularity Based on Time Signature')
# Out:
# Text(0.5, 1.0, 'Popularity Based on Time Signature')

# %%
sns.barplot(x = 't_sig1', y = 'popularity', data = dataframe)
plt.title('Popularity Based on Time Signature')
# Out:
# Text(0.5, 1.0, 'Popularity Based on Time Signature')

# %%
sns.barplot(x = 't_sig2', y = 'popularity', data = dataframe)
plt.title('Popularity Based on Time Signature')
# Out:
# Text(0.5, 1.0, 'Popularity Based on Time Signature')

# %%
sns.barplot(x = 't_key0', y = 'popularity', data = dataframe)
plt.title('Popularity Based on Key')
# Out:
# Text(0.5, 1.0, 'Popularity Based on Key')

# %%
sns.barplot(x = 't_key1', y = 'popularity', data = dataframe)
plt.title('Popularity Based on Key1')
# Out:
# Text(0.5, 1.0, 'Popularity Based on Key1')

# %%
sns.barplot(x = 't_key2', y = 'popularity', data = dataframe)
plt.title('Popularity Based on Key2')
# Out:
# Text(0.5, 1.0, 'Popularity Based on Key2')

# %%
sns.barplot(x = 't_mode0', y = 'popularity', data = dataframe)
plt.title('Popularity Based on Mode0')
# Out:
# Text(0.5, 1.0, 'Popularity Based on Mode0')

# %%
sns.barplot(x = 't_mode1', y = 'popularity', data = dataframe)
plt.title('Popularity Based on Mode1')
# Out:
# Text(0.5, 1.0, 'Popularity Based on Mode1')

# %%
sns.barplot(x = 't_mode2', y = 'popularity', data = dataframe)
plt.title('Popularity Based on Mode2')
# Out:
# Text(0.5, 1.0, 'Popularity Based on Mode2')

# %%
sns.jointplot(x = 't_acous0', y = 'popularity', data = dataframe)

# %%
sns.jointplot(x = 't_acous1', y = 'popularity', data = dataframe)

# %%
list_of_keys = dataframe['t_key0'].unique()
for i in range(len(list_of_keys)):
    dataframe.loc[dataframe['t_key0'] == list_of_keys[i], 't_key0'] = i
dataframe.sample(5)
# Out:
#             id            name release_date             artists  total_tracks  \
# 30650    30650  Enjoy Yourself   2010-01-01  Billy Currington,             11
# 47669    47669      Cojelo Ahi   1994-09-01     Antony Santos,             11
# 123352  123352            WWCD   2019-11-29          Griselda,             13
# 145057  145057     Spirit Bird   2012-01-01       Xavier Rudd,             13
# 83186    83186       VampMania   2020-05-02             Luci4,             11
#
#                                                   t_name0  \
# 30650                                        All Day Long
# 47669                                       La Barriguita
# 123352  Marchello (feat. Raekwon The Chef) - Raekwon T...
# 145057                                        Lioness Eye
# 83186                         Welkome 2 VampMania (Intro)
#
#                        t_name1                       t_name2  t_dur0  \
# 30650           Love Done Gone  Pretty Good At Drinkin' Beer  227520
# ...

# %%
dataframe.loc[dataframe["t_mode0"] == 'Major', "t_mode0"] = 1
dataframe.loc[dataframe["t_mode0"] == 'Minor', "t_mode0"] = 0
dataframe.sample(5)
# Out:
#             id                                     name release_date  \
# 52999    52999                                 Vinyl #1   2019-09-27
# 4789      4789                           Cuz I Love You   2019-04-19
# 129192  129192                              Gypsy Heart   2014-09-30
# 131152  131152  Panselinos Ke Kati - Is-Pnoi [A’ Meros]   2014-11-30
# 36895    36895                                Remington   2016-03-04
#
#                       artists  total_tracks            t_name0        t_name1  \
# 52999                Zivert,              9      Безболезненно  Beverly Hills
# 4789                  Lizzo,             11     Cuz I Love You    Like a Girl
# 129192       Colbie Caillat,             12         Live It Up          Blaze
# 131152  Pantelis Pantelidis,              8  Ah Ke Na 'rhosoun  Ta Shinia Sou
# 36895         Granger Smith,             15      Backroad Song        Tonight
#
#                          t_name2  t_dur0    t_dur1  ...  t_val0  t_val1  \
# ...

# %%
list_of_keys = dataframe['t_key1'].unique()
for i in range(len(list_of_keys)):
    dataframe.loc[dataframe['t_key1'] == list_of_keys[i], 't_key1'] = i
dataframe.sample(5)
# Out:
#             id                                               name  \
# 77746    77746  Uptown Girls [Music From and Inspired by the M...
# 7558      7558                                       Yed El Henna
# 6501      6501                                           Hot Pink
# 139602  139602           If This Isn’t Nice, I Don’t Know What Is
# 53441    53441                             Just A Matter of Slime
#
#        release_date            artists  total_tracks  \
# 77746          2003  Various Artists,             13
# 7558           2007           Fnaire,             18
# 6501     2019-11-07         Doja Cat,             12
# 139602   2021-08-13      Still Woozy,             13
# 53441    2021-08-13        YNW Melly,             12
#
#                                     t_name0  \
# 77746                          Charmed Life
# 7558                           Yamdah Salam
# 6501                              Cyber Sex
# 139602                                 Woof
# ...

# %%
dataframe.loc[dataframe["t_mode1"] == 'Major', "t_mode1"] = 1
dataframe.loc[dataframe["t_mode1"] == 'Minor', "t_mode1"] = 0
dataframe.sample(5)
# Out:
#             id                          name release_date             artists  \
# 131019  131019                          RTJ4   2020-06-03    Run The Jewels,
# 143596  143596                      Goldmine   2020-06-19     Gabby Barrett,
# 150721  150721  A Hangover You Don't Deserve         2004  Bowling For Soup,
# 137217  137217          Loud (Japan Version)   2010-01-01           Rihanna,
# 85801    85801                        D-beat   2021-02-21   Dbeatzitito Mix,
#
#         total_tracks                       t_name0  \
# 131019            11  yankee and the brave (ep. 4)
# 143596            13                        I Hope
# 150721            17                        Almost
# 137217            13                           S&M
# 85801              5                    Perreo sol
#
#                                          t_name1  \
# 131019  ooh la la (feat. Greg Nice & DJ Premier)
# 143596                                 Thank God
# ...

# %%
list_of_keys = dataframe['t_key2'].unique()
for i in range(len(list_of_keys)):
    dataframe.loc[dataframe['t_key2'] == list_of_keys[i], 't_key2'] = i
dataframe.sample(5)
# Out:
#             id              name release_date              artists  \
# 81267    81267   Easy Money Baby   2020-01-24        Myke Towers,
# 123330  123330           Romance   2019-12-06     Camila Cabello,
# 118994  118994  Pedestrian Verse         2013  Frightened Rabbit,
# 81974    81974         njkbibdrg   2019-12-01          Toshioman,
# 120849  120849            Ubuntu   2018-05-11            Piso 21,
#
#         total_tracks         t_name0                      t_name1  \
# 81267             18             MIB                           Tú
# 123330            14       Shameless                 Living Proof
# 118994            12     Acts of Man              Backyard Skulls
# 81974             20    Down on Trip             Suspended Skills
# 120849            13  La Vida Sin Ti  Te Amo (feat. Paulo Londra)
#
#                    t_name2  t_dur0    t_dur1  ...  t_val0  t_val1  t_val2  \
# 81267            Parcerita  134013  204746.0  ...  0.6310   0.825   0.775
# ...

# %%
dataframe.loc[dataframe["t_mode2"] == 'Major', "t_mode2"] = 1
dataframe.loc[dataframe["t_mode2"] == 'Minor', "t_mode2"] = 0
dataframe.sample(5)
# Out:
#             id                            name release_date  \
# 48346    48346          Tickets To My Downfall   2020-09-25
# 135693  135693                         Sublime   1996-07-30
# 76054    76054  Pink Friday ... Roman Reloaded   2011-01-01
# 33205    33205                         Pythons   2013-06-07
# 73074    73074                  Title (Deluxe)   2015-01-09
#
#                     artists  total_tracks                    t_name0  \
# 48346   Machine Gun Kelly,             15                title track
# 135693            Sublime,             17               Garden Grove
# 76054         Nicki Minaj,             19              Roman Holiday
# 33205        Surfer Blood,             10                Demon Dance
# 73074      Meghan Trainor,             15  The Best Part (Interlude)
#
#                     t_name1              t_name2  t_dur0    t_dur1  ...  \
# 48346             kiss kiss           drunk face  165967  138097.0  ...
# ...

# %%
dataframe.loc[dataframe['popularity'] < 57, 'popularity'] = 0 
dataframe.loc[dataframe['popularity'] >= 57, 'popularity'] = 1
dataframe.loc[dataframe['popularity'] == 1]
# Out:
#             id                                     name release_date  \
# 1            1                                   Nibiru   2019-11-29
# 2            2                                    DAMN.   2017-04-14
# 4            4                                  glisten   2018-05-04
# 6            6                               Pocahontas   1995-01-01
# 8            8                              Green River   1969-08-03
# ...        ...                                      ...          ...
# 159979  159979          Synchronicity (Remastered 2003)   1983-06-17
# 159982  159982  I met you when I was 18. (the playlist)   2018-05-31
# 159990  159990                                    Donda   2021-08-29
# 159992  159992                                   GEMINI   2017-09-22
# 159997  159997                   Country Again (Side A)   2021-04-30
#
#                                artists  total_tracks  \
# 1                              Ozuna,             18
# ...

# %%
# !pip install xgboost

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC, LinearSVC
from xgboost import XGBClassifier

from sklearn.metrics import make_scorer, accuracy_score, roc_auc_score 
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

# %%
features = ["t_acous0", "t_acous1", "t_acous2", "t_dance0", "t_dance1", "t_dance2", "t_dur0", "t_dur1", "t_dur2", "t_energy0",  "t_energy1", "t_energy2", "t_ins0", "t_ins1", "t_ins2", "t_key0", "t_key1", "t_key2", "t_live0", "t_live1", "t_live2", 
            "t_mode0", "t_mode1", "t_mode2", "t_speech0", "t_speech1", "t_speech2", "t_tempo0", "t_tempo1", "t_tempo2", "t_sig0", "t_sig1","t_sig2","t_val0","t_val1", "t_val2"]

# %%
training = dataframe.sample(frac = 0.8,random_state = 420)
X_train = training[features]
y_train = training['popularity']
X_test = dataframe.drop(training.index)[features]

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size = 0.2, random_state = 420)

# %%
LR_Model = LogisticRegression()
LR_Model.fit(X_train, y_train)
LR_Predict = LR_Model.predict(X_valid)
LR_Accuracy = accuracy_score(y_valid, LR_Predict)
print("Accuracy: " + str(LR_Accuracy))

LR_AUC = roc_auc_score(y_valid, LR_Predict) 
print("AUC: " + str(LR_AUC))
# Out:
# Accuracy: 0.5286473374148088
# AUC: 0.5282947989374018

# %%
RFC_Model = RandomForestClassifier()
RFC_Model.fit(X_train, y_train)
RFC_Predict = RFC_Model.predict(X_valid)
RFC_Accuracy = accuracy_score(y_valid, RFC_Predict)
print("Accuracy: " + str(RFC_Accuracy))

RFC_AUC = roc_auc_score(y_valid, RFC_Predict) 
print("AUC: " + str(RFC_AUC))
# Out:
# Accuracy: 0.9732586346309345
# AUC: 0.9733966019062503

# %%
KNN_Model = KNeighborsClassifier()
KNN_Model.fit(X_train, y_train)
KNN_Predict = KNN_Model.predict(X_valid)
KNN_Accuracy = accuracy_score(y_valid, KNN_Predict)
print("Accuracy: " + str(KNN_Accuracy))

KNN_AUC = roc_auc_score(y_valid, KNN_Predict) 
print("AUC: " + str(KNN_AUC))
# Out:
# Accuracy: 0.8848330830541759
# AUC: 0.8846208422537031

# %%
DT_Model = DecisionTreeClassifier()
DT_Model.fit(X_train, y_train)
DT_Predict = DT_Model.predict(X_valid)
DT_Accuracy = accuracy_score(y_valid, DT_Predict)
print("Accuracy: " + str(DT_Accuracy))

DT_AUC = roc_auc_score(y_valid, DT_Predict) 
print("AUC: " + str(DT_AUC))
# Out:
# Accuracy: 0.9362365715605868
# AUC: 0.9360771776777521

# %%
training_LSVC = training.sample(10000)
X_train_LSVC = training_LSVC[features]
y_train_LSVC = training_LSVC['popularity']
X_test_LSVC = dataframe.drop(training_LSVC.index)[features]
X_train_LSVC, X_valid_LSVC, y_train_LSVC, y_valid_LSVC = train_test_split(
    X_train_LSVC, y_train_LSVC, test_size = 0.2, random_state = 420)

# %%
LSVC_Model = DecisionTreeClassifier()
LSVC_Model.fit(X_train_LSVC, y_train_LSVC)
LSVC_Predict = LSVC_Model.predict(X_valid_LSVC)
LSVC_Accuracy = accuracy_score(y_valid_LSVC, LSVC_Predict)
print("Accuracy: " + str(LSVC_Accuracy))

LSVC_AUC = roc_auc_score(y_valid_LSVC, LSVC_Predict) 
print("AUC: " + str(LSVC_AUC))
# Out:
# Accuracy: 0.8145
# AUC: 0.8155449117131285

# %%
XGB_Model = XGBClassifier(objective = "binary:logistic", n_estimators = 10, seed = 123)
XGB_Model.fit(X_train, y_train)
XGB_Predict = XGB_Model.predict(X_valid)
XGB_Accuracy = accuracy_score(y_valid, XGB_Predict)
print("Accuracy: " + str(XGB_Accuracy))

XGB_AUC = roc_auc_score(y_valid, XGB_Predict) 
print("AUC: " + str(XGB_AUC))
# Out:
# [13:11:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy: 0.7683377613491972
# AUC: 0.7677282907424043

# %%
model_performance_accuracy = pd.DataFrame({'Model': ['LogisticRegression', 
                                                      'RandomForestClassifier', 
                                                      'KNeighborsClassifier',
                                                      'DecisionTreeClassifier',
                                                      'LinearSVC',
                                                      'XGBClassifier'],
                                            'Accuracy': [LR_Accuracy,
                                                         RFC_Accuracy,
                                                         KNN_Accuracy,
                                                         DT_Accuracy,
                                                         LSVC_Accuracy,
                                                         XGB_Accuracy]})

model_performance_AUC = pd.DataFrame({'Model': ['LogisticRegression', 
                                                      'RandomForestClassifier', 
                                                      'KNeighborsClassifier',
                                                      'DecisionTreeClassifier',
                                                      'LinearSVC',
                                                      'XGBClassifier'],
                                            'AUC': [LR_AUC,
                                                         RFC_AUC,
                                                         KNN_AUC,
                                                         DT_AUC,
                                                         LSVC_AUC,
                                                         XGB_AUC]})

# %%
model_performance_accuracy.sort_values(by = "Accuracy", ascending = False)
# Out:
#                     Model  Accuracy
# 1  RandomForestClassifier  0.973259
# 3  DecisionTreeClassifier  0.936237
# 2    KNeighborsClassifier  0.884833
# 4               LinearSVC  0.814500
# 5           XGBClassifier  0.768338
# 0      LogisticRegression  0.528647

# %%
model_performance_AUC.sort_values(by = "AUC", ascending = False)
# Out:
#                     Model       AUC
# 1  RandomForestClassifier  0.973397
# 3  DecisionTreeClassifier  0.936077
# 2    KNeighborsClassifier  0.884621
# 4               LinearSVC  0.815545
# 5           XGBClassifier  0.767728
# 0      LogisticRegression  0.528295

# %%
RFC_Model = RandomForestClassifier()
RFC_Model.fit(X_train, y_train)
RFC_Predict = RFC_Model.predict(X_valid)
RFC_Accuracy = accuracy_score(y_valid, RFC_Predict)
print("Accuracy: " + str(RFC_Accuracy))

RFC_AUC = roc_auc_score(y_valid, RFC_Predict) 
print("AUC: " + str(RFC_AUC))
# Out:
# Accuracy: 0.9730853644449579
# AUC: 0.9732208499397658
